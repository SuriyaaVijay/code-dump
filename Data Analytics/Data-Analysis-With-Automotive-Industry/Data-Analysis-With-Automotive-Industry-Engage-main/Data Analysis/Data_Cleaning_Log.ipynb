# %% [markdown]
# <a href="https://colab.research.google.com/github/KhushbooGupta2111/Data-Analysis-With-Automotive-Industry-Engage/blob/main/Data_Cleaning_Log.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Cleaning
#
# In this, we have cleaned data of cars_engage_2022.csv (The dataset provided by Microsoft for Engage challenge)
#
# The dataset is huge and needed an ample amount of cleaning for further processes in data analysis, data visualisation and training the machine learning model
#
# The process of data cleaning included:
#
# 1. Handling Missing Data
# 2.

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing Dataset

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Dataset is available in the github repository under the Automotive_Industry_Data directory

# %%
auto_data = pd.read_csv('gdrive/My Drive/cars_engage_2022.csv')

# %% [markdown]
# Data Loaded.

# %%
auto_data["Clock"].value_counts()
# Out:
# Digital            1058
# Analog               41
# Yes                  39
# Digital, Analog       4
# Name: Clock, dtype: int64

# %% [markdown]
# Cleaning the data

# %% [markdown]
# 1. Removing the index column

# %%
auto_data = auto_data.drop(auto_data.columns[0] , axis = 1)
auto_data
# Out:
#             Make      Model        Variant Ex-Showroom_Price Displacement  \
# 0           Tata  Nano Genx             Xt      Rs. 2,92,667       624 cc
# 1           Tata  Nano Genx             Xe      Rs. 2,36,447       624 cc
# 2           Tata  Nano Genx        Emax Xm      Rs. 2,96,661       624 cc
# 3           Tata  Nano Genx            Xta      Rs. 3,34,768       624 cc
# 4           Tata  Nano Genx             Xm      Rs. 2,72,223       624 cc
# ...          ...        ...            ...               ...          ...
# 1271       Honda       City   Vx Mt Diesel     Rs. 13,02,000      1498 cc
# 1272       Honda       City   Zx Mt Diesel     Rs. 14,21,000      1498 cc
# 1273       Honda       City  Zx Cvt Petrol     Rs. 14,31,000      1497 cc
# 1274       Honda       City   V Cvt Petrol     Rs. 12,01,000      1497 cc
# 1275  Mitsubishi    Montero         3.2 At     Rs. 68,62,560      3200 cc
#
#       Cylinders  Valves_Per_Cylinder               Drivetrain  \
# ...

# %% [markdown]
# 2. Checking for all null values in all the columns in the dataset

# %%
null_values_dictionary = auto_data.isnull().sum().to_dict()
counter = 0;

for key , val in null_values_dictionary.items():
  if(val != 0):
    counter += 1
    print(str(key) + " - " + str(val))
  
print("The number of columns which have null values is: " + str(counter));
# Out:
# Make - 75
# Displacement - 12
# Cylinders - 66
# Valves_Per_Cylinder - 102
# Drivetrain - 7
# Cylinder_Configuration - 13
# Emission_Norm - 11
# Engine_Location - 43
# Fuel_System - 8
# Fuel_Tank_Capacity - 69
# Height - 1
# Width - 12
# Body_Type - 6
# Doors - 4
# City_Mileage - 555
# Highway_Mileage - 800
# ARAI_Certified_Mileage - 114
# ARAI_Certified_Mileage_for_CNG - 1249
# Kerb_Weight - 365
# Gears - 105
# Ground_Clearance - 289
# Front_Brakes - 25
# Rear_Brakes - 25
# Front_Suspension - 59
# Rear_Suspension - 46
# Front_Track - 667
# Rear_Track - 676
# Front_Tyre_&_Rim - 49
# Rear_Tyre_&_Rim - 48
# Power_Steering - 57
# Power_Windows - 97
# Power_Seats - 893
# Keyless_Entry - 274
# Torque - 2
# Odometer - 43
# Speedometer - 45
# Tachometer - 13
# Tripmeter - 60
# Seating_Capacity - 6
# Seats_Material - 12
# Type - 1
# Wheelbase - 20
# Wheels_Size - 56
# Start_/_Stop_Button - 678
# 12v_Power_Outlet - 154
# Audiosystem - 44
# Aux-in_Compatibility - 284
# ...

# %%
auto_data.shape
# Out:
# (1276, 140)

# %% [markdown]
# 3. Make

# %%
company_names_list = auto_data.Make.unique().tolist()
print(type(company_names_list))
print(len(company_names_list))

for company in company_names_list:
  print(company)
# Out:
# <class 'list'>
# 40
# Tata
# Datsun
# Renault
# Maruti Suzuki
# Hyundai
# Premier
# Toyota
# Nissan
# Volkswagen
# Ford
# Mahindra
# Fiat
# Honda
# Jeep
# Isuzu
# Skoda
# Audi
# nan
# Dc
# Mini
# Volvo
# Jaguar
# Bmw
# Land Rover
# Porsche
# Lexus
# Maserati
# Lamborghini
# Bentley
# Ferrari
# Aston Martin
# Bugatti
# Bajaj
# Icml
# Force
# Mg
# Kia
# Land Rover Rover
# Mitsubishi
# Maruti Suzuki R

# %%
auto_data_Make = auto_data.Make.replace("Maruti Suzuki R" , "Maruti Suzuki") 
auto_data.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
for company in company_names_list:
   print(company)
# Out:
# Tata
# Datsun
# Renault
# Maruti Suzuki
# Hyundai
# Premier
# Toyota
# Nissan
# Volkswagen
# Ford
# Mahindra
# Fiat
# Honda
# Jeep
# Isuzu
# Skoda
# Audi
# nan
# Dc
# Mini
# Volvo
# Jaguar
# Bmw
# Land Rover
# Porsche
# Lexus
# Maserati
# Lamborghini
# Bentley
# Ferrari
# Aston Martin
# Bugatti
# Bajaj
# Icml
# Force
# Mg
# Kia
# Land Rover Rover
# Mitsubishi
# Maruti Suzuki R

# %%
company_names = auto_data.Make
print(company_names)
print(type(company_names))
# Out:
# 0             Tata
# 1             Tata
# 2             Tata
# 3             Tata
# 4             Tata
#            ...
# 1271         Honda
# 1272         Honda
# 1273         Honda
# 1274         Honda
# 1275    Mitsubishi
# Name: Make, Length: 1276, dtype: object
# <class 'pandas.core.series.Series'>

# %%
np.where(company_names.isnull())[0]
# Out:
# array([ 252,  253,  254,  255,  256,  257,  258,  303,  307,  308,  309,
#         310,  311,  322,  323,  324,  328,  329,  334,  335,  340,  349,
#         350,  351,  353,  354,  793,  794,  795,  796,  797,  798,  799,
#         800,  806,  809,  810,  811,  821,  859,  860,  861,  862,  879,
#         880,  883,  884,  885,  886,  887,  888,  889,  890,  891, 1025,
#        1026, 1033, 1034, 1035, 1036, 1037, 1038, 1047, 1048, 1049, 1146,
#        1147, 1148, 1149, 1150, 1151, 1219, 1220, 1251, 1252])

# %%
company_names.isna().sum()
# Out:
# 75

# %%
for name in company_names:
  print(name)
# Out:
# Tata
# Tata
# Tata
# Tata
# Tata
# Tata
# Datsun
# Datsun
# Datsun
# Datsun
# Datsun
# Datsun
# Renault
# Renault
# Renault
# Renault
# Renault
# Renault
# Renault
# Renault
# Renault
# Renault
# Renault
# Renault
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Datsun
# Datsun
# Datsun
# Datsun
# Datsun
# Datsun
# Datsun
# Datsun
# Datsun
# Maruti Suzuki
# Maruti Suzuki
# Hyundai
# Hyundai
# Hyundai
# Hyundai
# Hyundai
# Hyundai
# Hyundai
# Hyundai
# Tata
# Tata
# Tata
# Tata
# Tata
# Tata
# Tata
# Tata
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Maruti Suzuki
# Renault
# Renault
# Renault
# Renault
# Premier
# Premier
# Premier
# Premier
# Premier
# Premier
# Toyota
# Toyota
# ...

# %% [markdown]
# Model -- No null values present in this
# Variant -- No null values present in this

# %%
auto_data.isnull().sum().to_dict()
# Out:
# {'12v_Power_Outlet': 154,
#  '3_Point_Seat-Belt_in_Middle_Rear_Seat': 1225,
#  'ABS_(Anti-lock_Braking_System)': 132,
#  'ARAI_Certified_Mileage': 114,
#  'ARAI_Certified_Mileage_for_CNG': 1249,
#  'ASR_/_Traction_Control': 834,
#  'Adjustable_Headrests': 250,
#  'Adjustable_Steering_Column': 191,
#  'Airbags': 132,
#  'Ambient_Lightning': 1220,
#  'Android_Auto': 1103,
#  'Apple_CarPlay': 1103,
#  'Audiosystem': 44,
#  'Auto-Dimming_Rear-View_Mirror': 620,
#  'Automatic_Headlamps': 774,
#  'Aux-in_Compatibility': 284,
#  'Average_Fuel_Consumption': 345,
#  'Average_Speed': 512,
#  'Basic_Warranty': 440,
#  'Battery': 1263,
#  'Bluetooth': 292,
#  'Body_Type': 6,
#  'Boot-lid_Opener': 14,
#  'Boot_Space': 249,
#  'CD_/_MP3_/_DVD_Player': 309,
#  'Cargo/Boot_Lights': 1155,
#  'Central_Locking': 149,
#  'Child_Safety_Locks': 75,
#  'Cigarette_Lighter': 682,
#  'City_Mileage': 555,
#  'Clock': 134,
#  'Compression_Ratio': 917,
#  'Cooled_Glove_Box': 645,
#  'Cruise_Control': 727,
# ...

# %%
num_features=[col for col in auto_data.columns if auto_data[col].dtypes !='O']
cat_features=[col for col in auto_data.columns if col not in num_features]
print("categorical features:\n{}".format(cat_features),"\n")
print("numerical features:\n{}".format(num_features))
# Out:
# categorical features:
# ...

# %% [markdown]
# Function which removes all the values after the first spacebar in the column

# %% [markdown]
# Function Built for cleaning Delimiter
#
# (Note: This just removes the extra units. For converting the values from string to integer, run the string_to_numeric function, which is mentioned below)

# %%
auto_data.isnull().sum()
# Out:
# Make                   75
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
# Displacement           12
#                      ...
# USB_Ports            1247
# Heads-Up_Display     1225
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 140, dtype: int64

# %%
# This function is used to eliminate the delimiter values in the columns
def unit_delimiter(column_name , removing_substring):
  auto_data[column_name] = auto_data[column_name].apply(str).str.replace(' ' + removing_substring , '');

# %% [markdown]
# Function Built for converting values from string to integer
#
# (Note: Run this after you have executed the function unit_delimiter)

# %%
def string_to_numeric(column_name):
  auto_data[column_name] = auto_data[column_name].fillna(0)
  auto_data[column_name] = auto_data[column_name].replace("nan" , 0 , regex = True)
  auto_data[column_name] = pd.to_numeric(auto_data[column_name] )

# %% [markdown]
# A function which combines these 2 functions

# %%
def delimiter_and_numeric(column_name , removing_substring):
  unit_delimiter(column_name , removing_substring)
  string_to_numeric(column_name)

# %%
def all_before_space(column_name):
  auto_data[column_name] = auto_data[column_name].str.split(" " , n = 1 , expand = True)[0]

# %% [markdown]
# :::::Function which replaces any extra character from the column

# %%
def replace_extra_characters(column_name , character , replacement = ''):
  auto_data[column_name] = auto_data[column_name].str.replace(character , replacement)
