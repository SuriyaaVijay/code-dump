# %% [markdown]
# **▶** **TASK 5: CREDIT CARD FRAUD DETECTION**<br>
# --Author: Vaibhav Kushwaha<br>
# --Batch: August<br>
# -- Domain: Data Science

# %% [markdown]
# Importing the dependenices

# %%
import numpy as np #for making arrays
import pandas as pd #it helps to make data frame(structure table)
from sklearn.model_selection import train_test_split #allows data to divide into training data and testing data
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\pc\Downloads\creditcardfraud.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pc/Downloads/creditcardfraud.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import numpy as np #for making arrays
#       <a href='vscode-notebook-cell:/c%3A/Users/pc/Downloads/creditcardfraud.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd #it helps to make data frame(structure table)
#       <a href='vscode-notebook-cell:/c%3A/Users/pc/Downloads/creditcardfraud.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> from sklearn.model_selection import train_test_split #allows data to divide into training data and testing data
#
# ModuleNotFoundError: No module named 'numpy'

# %%
#loading the dataset to panda dataframe
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
# first five rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 53566  46047 -2.885416 -2.647887  1.903441  3.726885  3.800798 -1.644480
# 53567  46048  1.061410  0.045830  0.970401  1.102883 -0.490685  0.219968
# 53568  46048 -0.202740  0.295074  1.924698  1.009344 -0.235931 -0.272232
# 53569  46048 -0.730116  0.796820  2.122484 -1.318082  0.019762 -0.857857
# 53570  46050  0.791672 -0.522991  0.036747  1.204803 -0.262390 -0.056153
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 53566 -1.924198  0.707696 -1.070468  ...  0.284893 -0.268122  0.977417
# 53567 -0.424285  0.235960  0.016498  ...  0.033158  0.067127  0.053801
# 53568  0.261015 -0.162146 -0.583849  ...  0.321731  1.056540  0.093902
# 53569  0.975752 -0.399896  0.359189  ... -0.149736  0.093479 -0.056586
# 53570  0.263614 -0.130209  0.125423  ...  0.013131 -0.000000       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# 53566  0.136853 -1.144367 -0.535616  0.098494  0.305740   19.02    0.0
# 53567 -0.010221  0.209877 -0.484136  0.057583  0.028018   28.70    0.0
# 53568  0.608566 -0.931546  0.466156  0.016695 -0.024568   54.81    0.0
# 53569  0.650087 -0.473889  0.662115  0.060486 -0.208536    4.53    0.0
# 53570       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
# data set info
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53571 entries, 0 to 53570
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    53571 non-null  int64
#  1   V1      53571 non-null  float64
#  2   V2      53571 non-null  float64
#  3   V3      53571 non-null  float64
#  4   V4      53571 non-null  float64
#  5   V5      53571 non-null  float64
#  6   V6      53571 non-null  float64
#  7   V7      53571 non-null  float64
#  8   V8      53571 non-null  float64
#  9   V9      53571 non-null  float64
#  10  V10     53571 non-null  float64
#  11  V11     53571 non-null  float64
#  12  V12     53571 non-null  float64
#  13  V13     53571 non-null  float64
#  14  V14     53571 non-null  float64
#  15  V15     53571 non-null  float64
#  16  V16     53571 non-null  float64
#  17  V17     53571 non-null  float64
#  18  V18     53571 non-null  float64
#  19  V19     53571 non-null  float64
#  20  V20     53571 non-null  float64
#  21  V21     53571 non-null  float64
#  22  V22     53571 non-null  float64
#  23  V23     53570 non-null  float64
#  24  V24     53570 non-null  float64
#  25  V25     53570 non-null  float64
#  26  V26     53570 non-null  float64
#  27  V27     53570 non-null  float64
#  28  V28     53570 non-null  float64
#  29  Amount  53570 non-null  float64
#  30  Class   53570 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 12.7 MB

# %%
# checking the number of missinng values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# check the disitribution of legit and fraudlent transaction
credit_card_data['Class'].value_counts()
# Out:
# 0.0    53417
# 1.0      153
# Name: Class, dtype: int64

# %% [markdown]
# This data set is unbalanced
#
# 0--> normal trnsction
# 1--> fraudlent transaction

# %%
# separating the data for analysis
legit= credit_card_data[credit_card_data.Class == 0]
fraud= credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (53417, 31)
# (153, 31)

# %%
# statistical measures of data
legit.Amount.describe()
# Out:
# count    53417.000000
# mean        94.251260
# std        252.353693
# min          0.000000
# 25%          7.680000
# 50%         25.520000
# 75%         86.650000
# max      12910.930000
# Name: Amount, dtype: float64

# %%
# statistical measures of data
fraud.Amount.describe()
# Out:
# count     153.000000
# mean       97.616013
# std       230.026856
# min         0.000000
# 25%         1.000000
# 50%         7.610000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %% [markdown]
# Imp point to remember
# ***the mean of fraud transaction should be higer than the legit transactions

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#               Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    30011.81811 -0.222505 -0.014659   0.722511  0.163565 -0.242775
# 1.0    27472.24183 -7.468948  5.326389 -10.100308  5.793812 -5.528864
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.109604 -0.097131  0.042665  0.104805  ...  0.046251 -0.031568
# 1.0   -2.230554 -7.865700  3.617647 -3.492917  ...  0.455720  0.891045
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.106396 -0.038408  0.008094  0.134794  0.019825  0.002289  0.003902
# 1.0   -0.218399 -0.277419 -0.084305  0.240593  0.136258  0.586389  0.028185
#
#           Amount
# Class
# 0.0    94.251260
# 1.0    97.616013
#
# [2 rows x 30 columns]

# %% [markdown]
# under-sampling --> used to dealing with unbalanced data

# %% [markdown]
# build a sample data set containing similar distribution of normal transaction and the fraudlent transaction

# %% [markdown]
# number of fraudlent transaction= 56

# %%
legit_sample = legit.sample(n=56)

# %% [markdown]
# concatenating two Dataframes

# %%
new_dataset =pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 5274    5118 -1.249104  1.922419  0.702726  0.283883 -0.248844  0.032979
# 1123     871  1.184127  0.626778  0.714077  2.485282 -0.157646 -0.524432
# 6185    7205  1.122298  0.667824  0.292862  2.605763  0.348187 -0.388651
# 24762  33372 -0.567183 -0.100837  2.010988 -0.916075 -0.108690  1.077391
# 4123    3745  1.066156 -0.735777  0.656479 -0.545533 -0.461528  0.869502
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 5274  -0.886449 -2.208807  0.396504  ... -1.596173 -0.335529  0.307676
# 1123   0.161986 -0.145609 -0.806322  ... -0.065100 -0.212762  0.014422
# 6185   0.459318 -0.291110  0.279463  ... -0.548831 -1.555734  0.076899
# 24762  0.477887 -0.066144 -0.685927  ... -0.241586  0.118585 -0.352966
# 4123  -0.872992  0.281217  0.455085  ... -0.062278 -0.059345  0.253112
#
#             V24       V25       V26       V27       V28  Amount  Class
# 5274  -0.047598 -0.285985  0.047610  0.084758  0.058519   18.69    0.0
# 1123   0.385381  0.438366 -0.076374 -0.005936  0.026247    6.56    0.0
# 6185  -0.237795  0.315708 -0.391855 -0.064435  0.023084   67.04    0.0
# 24762 -0.876982  0.070924 -0.373954 -0.289236 -0.364829   79.00    0.0
# 4123  -0.719223 -0.175876 -0.418784  0.042509  0.016916   78.09    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 50211  44393 -4.617461  3.663395 -5.297446  3.880960 -3.263551 -0.918547
# 50537  44532 -0.234922  0.355413  1.972183 -1.255593 -0.681387 -0.665732
# 52466  45463 -1.476893  2.122314 -1.229470  1.201849 -0.343264 -1.317704
# 52521  45501  1.001992  0.047938 -0.349002  1.493958  0.186939  0.190966
# 52584  45541 -1.519244  2.308492 -1.503599  2.064101 -1.000845 -1.016897
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 50211 -5.715262  0.831040 -2.457034  ...  2.698175 -0.027081  0.366775
# 50537  0.059110 -0.003153  1.122451  ...  0.220670  0.912107 -0.286338
# 52466 -1.528142 -0.620953 -1.213040  ...  1.186036 -0.040215 -0.238930
# 52521 -0.001112  0.147140  0.580415  ... -0.334417 -1.014315 -0.128427
# 52584 -2.059731 -0.275166 -1.562206  ...  1.307871  0.102826 -0.017746
#
#             V24       V25       V26       V27       V28  Amount  Class
# 50211 -0.123011 -0.300457 -0.239996 -0.183463 -0.073360    1.00    1.0
# 50537  0.451208  0.188315 -0.531846  0.123185  0.039581    1.00    1.0
# 52466  0.110144  0.045418 -0.569232  0.481019 -0.047555    1.00    1.0
# 52521 -0.946242  0.456090 -0.453206  0.046627  0.064698  105.99    1.0
# 52584  0.149696 -0.096602 -0.369115 -0.019244 -0.208319    1.00    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# 1.0    153
# 0.0     56
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    31116.982143 -0.332585 -0.088825   0.623142  0.401094  0.099055
# 1.0    27472.241830 -7.468948  5.326389 -10.100308  5.793812 -5.528864
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.148066 -0.301831  0.032463 -0.119217  ... -0.121235 -0.069854
# 1.0   -2.230554 -7.865700  3.617647 -3.492917  ...  0.455720  0.891045
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.116363 -0.261902  0.082686  0.038254 -0.079954  0.131581 -0.092500
# 1.0   -0.218399 -0.277419 -0.084305  0.240593  0.136258  0.586389  0.028185
#
#           Amount
# Class
# 0.0    68.848929
# 1.0    97.616013
#
# [2 rows x 30 columns]

# %% [markdown]
# split the data into features and targets

# %%
x= new_dataset.drop(columns='Class' , axis=1)
y=new_dataset['Class']

# %%
print(x)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 5274    5118 -1.249104  1.922419  0.702726  0.283883 -0.248844  0.032979
# 1123     871  1.184127  0.626778  0.714077  2.485282 -0.157646 -0.524432
# 6185    7205  1.122298  0.667824  0.292862  2.605763  0.348187 -0.388651
# 24762  33372 -0.567183 -0.100837  2.010988 -0.916075 -0.108690  1.077391
# 4123    3745  1.066156 -0.735777  0.656479 -0.545533 -0.461528  0.869502
# ...      ...       ...       ...       ...       ...       ...       ...
# 50211  44393 -4.617461  3.663395 -5.297446  3.880960 -3.263551 -0.918547
# 50537  44532 -0.234922  0.355413  1.972183 -1.255593 -0.681387 -0.665732
# 52466  45463 -1.476893  2.122314 -1.229470  1.201849 -0.343264 -1.317704
# 52521  45501  1.001992  0.047938 -0.349002  1.493958  0.186939  0.190966
# 52584  45541 -1.519244  2.308492 -1.503599  2.064101 -1.000845 -1.016897
#
#              V7        V8        V9  ...       V20       V21       V22  \
# 5274  -0.886449 -2.208807  0.396504  ...  0.585216 -1.596173 -0.335529
# 1123   0.161986 -0.145609 -0.806322  ... -0.111995 -0.065100 -0.212762
# 6185   0.459318 -0.291110  0.279463  ... -0.037518 -0.548831 -1.555734
# 24762  0.477887 -0.066144 -0.685927  ... -0.507841 -0.241586  0.118585
# 4123  -0.872992  0.281217  0.455085  ...  0.020887 -0.062278 -0.059345
# ...         ...       ...       ...  ...       ...       ...       ...
# 50211 -5.715262  0.831040 -2.457034  ... -0.346456  2.698175 -0.027081
# 50537  0.059110 -0.003153  1.122451  ... -0.003469  0.220670  0.912107
# 52466 -1.528142 -0.620953 -1.213040  ...  0.276893  1.186036 -0.040215
# 52521 -0.001112  0.147140  0.580415  ...  0.016004 -0.334417 -1.014315
# 52584 -2.059731 -0.275166 -1.562206  ...  0.175019  1.307871  0.102826
#
#             V23       V24       V25       V26       V27       V28  Amount
# 5274   0.307676 -0.047598 -0.285985  0.047610  0.084758  0.058519   18.69
# 1123   0.014422  0.385381  0.438366 -0.076374 -0.005936  0.026247    6.56
# 6185   0.076899 -0.237795  0.315708 -0.391855 -0.064435  0.023084   67.04
# 24762 -0.352966 -0.876982  0.070924 -0.373954 -0.289236 -0.364829   79.00
# 4123   0.253112 -0.719223 -0.175876 -0.418784  0.042509  0.016916   78.09
# ...         ...       ...       ...       ...       ...       ...     ...
# 50211  0.366775 -0.123011 -0.300457 -0.239996 -0.183463 -0.073360    1.00
# 50537 -0.286338  0.451208  0.188315 -0.531846  0.123185  0.039581    1.00
# 52466 -0.238930  0.110144  0.045418 -0.569232  0.481019 -0.047555    1.00
# 52521 -0.128427 -0.946242  0.456090 -0.453206  0.046627  0.064698  105.99
# 52584 -0.017746  0.149696 -0.096602 -0.369115 -0.019244 -0.208319    1.00
#
# [209 rows x 30 columns]

# %%
print(y)
# Out:
# 5274     0.0
# 1123     0.0
# 6185     0.0
# 24762    0.0
# 4123     0.0
#         ...
# 50211    1.0
# 50537    1.0
# 52466    1.0
# 52521    1.0
# 52584    1.0
# Name: Class, Length: 209, dtype: float64

# %% [markdown]
# split data into training data and testing data

# %%
x_train, x_test , y_train, y_test = train_test_split(x,y, test_size=0.2 , stratify= y, random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (209, 30) (167, 30) (42, 30)

# %% [markdown]
# model training

# %% [markdown]
# logistic regression

# %%
model= LogisticRegression(max_iter=100000)

# %%
# training the logistic Regression model with training data
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=100000)

# %% [markdown]
# model evaluation

# %%
# accuracy score on training data
x_train_prediction= model.predict(x_train)
training_data_accuracy=accuracy_score(x_train_prediction, y_train)

# %%
print('accuracy on data :', training_data_accuracy)
# Out:
# accuracy on data : 0.9760479041916168

# %%
#accuracy on test data
x_test_prediction= model.predict(x_test)
test_data_accuracy=accuracy_score(x_test_prediction, y_test)

# %%
print('accuracy score on test data :' , test_data_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\pc\Downloads\creditcardfraud.ipynb Cell 42 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pc/Downloads/creditcardfraud.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> print('accuracy score on test data :' , test_data_accuracy)
#
# NameError: name 'test_data_accuracy' is not defined
